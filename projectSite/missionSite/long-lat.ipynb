# %%
# !pip install plotly

# %%
import plotly.graph_objects as go
import pandas as pd

df_airports = pd.read_csv('https://raw.githubusercontent.com/plotly/datasets/master/2011_february_us_airport_traffic.csv', )
#relevent airlines we want to use for Flight Anaylsis map
airlines = ['ATL','BOS','CLT', 'DEN','DFW','DTW','EWR','IAD','JFK','LAX','LGA','MIA','OAK','ORD','PHL', 'SFO']

df = df_airports[df_airports['iata'].isin(airlines)]

df
# Out:
#    iata                             airport               city state country  \
# 0   ORD        Chicago O'Hare International            Chicago    IL     USA
# 1   ATL   William B Hartsfield-Atlanta Intl            Atlanta    GA     USA
# 2   DFW     Dallas-Fort Worth International  Dallas-Fort Worth    TX     USA
# 4   DEN                         Denver Intl             Denver    CO     USA
# 6   SFO         San Francisco International      San Francisco    CA     USA
# 7   LAX           Los Angeles International        Los Angeles    CA     USA
# 9   CLT     Charlotte/Douglas International          Charlotte    NC     USA
# 12  EWR                         Newark Intl             Newark    NJ     USA
# 14  PHL                   Philadelphia Intl       Philadelphia    PA     USA
# 17  LGA                           LaGuardia           New York    NY     USA
# 19  IAD     Washington Dulles International          Chantilly    VA     USA
# ...

# %%
df_flight_paths = pd.read_csv('https://raw.githubusercontent.com/plotly/datasets/master/2011_february_aa_flight_paths.csv')
df_flight_paths.head()
# Out:
#    start_lat  start_lon    end_lat     end_lon airline airport1 airport2  cnt
# 0  32.895951 -97.037200  35.040222 -106.609194      AA      DFW      ABQ  444
# 1  41.979595 -87.904464  30.194533  -97.669872      AA      ORD      AUS  166
# 2  32.895951 -97.037200  41.938874  -72.683228      AA      DFW      BDL  162
# 3  18.439417 -66.001833  41.938874  -72.683228      AA      SJU      BDL   56
# 4  32.895951 -97.037200  33.562943  -86.753550      AA      DFW      BHM  168

# %%
import pandas as pd
import pyspark
from pyspark.sql import SparkSession
from pyspark.sql.functions import avg, max, min, month, year, format_number, col, count, round
import time
import mysql.connector

# In[2]:


# Start a Spark session
from pyspark.sql import SparkSession
# change number of workers in master argument below (1,2,4,*)
spark = SparkSession.builder \
    .config("spark.jars", "/usr/share/java/mysql-connector-j-8.0.31.jar") \
    .master("local[*]").appName("AirportQueries").getOrCreate()
# Read in data

# Create Database Connection

dbConnection = mysql.connector.connect(user = "Group4", password = "Group4!")
dbCursor = dbConnection.cursor()
dbCursor.execute("USE Project;")
dbCursor.execute("SELECT * FROM AverageFlightPrices;")
(dbCursor.fetchall())
# Out:
# 265.08
