# %%
import pandas as pd
df = pd.read_csv('itineraries.csv')

# %%
df
# Out:
#                                      legId  searchDate  flightDate  \
# 0         9ca0e81111c683bec1012473feefd28f  2022-04-16  2022-04-17
# 1         79eda9f841e226a1e2121d74211e595c  2022-04-16  2022-04-17
# 2         c38a6e4b807d15541e5866676febcbec  2022-04-16  2022-04-17
# 3         cb345693479e84838dfaac346b8e8d6a  2022-04-16  2022-04-17
# 4         676e25bb0ec021d335241354b668c674  2022-04-16  2022-04-17
# ...                                    ...         ...         ...
# 11111995  2b80987af62b6d5cd31f8ffd8c871583  2022-08-11  2022-09-13
# 11111996  0ea8a682bc37360d008e9fed75219ec9  2022-08-11  2022-09-13
# 11111997  8568054af4498ae302535a02f36cbcb2  2022-08-11  2022-09-13
# 11111998  dc85f5f815be77dcf8236b1b4a172da8  2022-08-11  2022-09-13
# 11111999  1d233041bd3ff65086b5d92b5b47281a  2022-08-11  2022-09-13
#
#          startingAirport destinationAirport travelDuration  isRefundable  \
# 0                    ATL                BOS        PT2H29M         False
# ...

# %%
df2 = df.loc[:, df.columns != 'Unnamed: 0'] #removes extra column

# %%
#df2.to_csv('itineraries.csv', index=False)

# %%
df2
# Out:
#                                      legId  searchDate  flightDate  \
# 0         9ca0e81111c683bec1012473feefd28f  2022-04-16  2022-04-17
# 1         79eda9f841e226a1e2121d74211e595c  2022-04-16  2022-04-17
# 2         c38a6e4b807d15541e5866676febcbec  2022-04-16  2022-04-17
# 3         cb345693479e84838dfaac346b8e8d6a  2022-04-16  2022-04-17
# 4         676e25bb0ec021d335241354b668c674  2022-04-16  2022-04-17
# ...                                    ...         ...         ...
# 11111995  2b80987af62b6d5cd31f8ffd8c871583  2022-08-11  2022-09-13
# 11111996  0ea8a682bc37360d008e9fed75219ec9  2022-08-11  2022-09-13
# 11111997  8568054af4498ae302535a02f36cbcb2  2022-08-11  2022-09-13
# 11111998  dc85f5f815be77dcf8236b1b4a172da8  2022-08-11  2022-09-13
# 11111999  1d233041bd3ff65086b5d92b5b47281a  2022-08-11  2022-09-13
#
#          startingAirport destinationAirport travelDuration  isRefundable  \
# 0                    ATL                BOS        PT2H29M         False
# ...
